# %% [markdown]
# # Web Scrapping GodsUnchained
# Nesse notebook vamos fazer um web scrapping da pagina https://gudecks.com/meta/card-rankings para pegar informações sobre as cartas e gerar um documendo csv.

# %% [markdown]
# ## 1. Programa que pega informações sobre as cartas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from time import sleep

options = Options()
options.add_argument('window-size=800,800')

navegador = webdriver.Chrome()
navegador.get('https://gudecks.com/meta/card-rankings')

sleep(10)

but = navegador.find_element(By.XPATH, '//*[@id="root"]/div[3]/button')
but.click()

sleep(0.5)

informations = [] # Todas as paginas
for i in range(49):
    informations.append(BeautifulSoup(navegador.page_source, 'html.parser'))
    but = navegador.find_element(By.XPATH, '//*[@id="root"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[3]/button')
    but.click()
    sleep(0.025)

all_cards = [] 
for site in informations:
    cards = site.findAll('div', attrs={'class':'rt-tr-group'})
    for card in cards:
        little_list = []
        
        little_list.append(site.find('div', attrs={'class':'card-ranking-name'}).text) # Nome da carta
        little_list.extend([atr.text for atr in card.findAll('div', attrs={'class':'rt-td react-table-cell'})]) #Info das cartas

        all_cards.append(little_list)
    
    

    
print(all_cards)
# Out:
# [['Magic Missile Launcher', 'War', 'Etherbots', '1.688', '0.8%', '1.75', '68.1%', '68.3%', '0.1770'], ['Magic Missile Launcher', 'War', 'Genesis', '1.154', '0.5%', '1.00', '64.6%', '64.6%', '0.1659'], ['Magic Missile Launcher', 'War', 'Genesis', '251', '0.1%', '1.00', '63.7%', '63.7%', '0.0335'], ['Magic Missile Launcher', 'War', 'Genesis', '487', '0.2%', '1.33', '63.2%', '63.2%', '0.0004'], ['Magic Missile Launcher', 'Magic', 'Genesis', '360', '0.4%', '1.00', '63.1%', '63.1%', '0.0449'], ['Magic Missile Launcher', 'Neutral', 'Core', '7.098', '0.9%', '1.08', '62.7%', '62.9%', '0.0001'], ['Magic Missile Launcher', 'Neutral', 'Core', '9.632', '1.2%', '1.13', '61.6%', '61.8%', '0.0001'], ['Magic Missile Launcher', 'Death', 'Genesis', '2.222', '3.2%', '1.80', '61.1%', '61.5%', '0.1500'], ['Magic Missile Launcher', 'Neutral', 'Core', '20.327', '2.5%', '1.20', '61.1%', '61.5%', '0.0001'], ['Magic Missile Launcher', 'War', 'Genesis', '6.061', '2.8%', '1.79', '60.7%', '61.1%', '0.0265'], ['Magic Missile Launcher', 'War', 'Genesis', '1.155', '0.5%', '1.00', '60.6%', '60.7%', '0.1379'], ['Magic Missile Launcher', 'Neutral', 'Genesis', '1.750', '0.2%', '1.52', '60.2%', '60.3%', '0.0036'], ['Magic Missile Launcher', 'Nature', 'Genesis', '1.291', '0.6%', '1.06', '60.1%', '60.2%', '0.0148'], ['Magic Missile Launcher', 'War', 'Trial', '5.452', '2.5%', '1.00', '60.1%', '60.5%', '0.0424'], ['Magic Missile Launcher', 'Neutral', 'Core', '15.072', '1.9%', '1.13', '59.8%', '60.1%', '0.0003'], ['Magic Missile Launcher', 'Neutral', 'Core', '10.423', '1.3%', '1.08', '59.7%', '59.8%', '0.0001'], ['Magic Missile Launcher', 'Neutral', 'Core', '13.430', '1.7%', '1.11', '59.7%', '60.0%', '0.0001'], ['Magic Missile Launcher', 'Neutral', 'Core', '4.285', '0.5%', '1.08', '59.6%', '59.7%', '0.0006'], ['Magic Missile Launcher', 'Neutral', 'Core', '23.913', '3.0%', '1.13', '59.5%', '60.0%', '0.0001'], ['Magic Missile Launcher', 'Neutral', 'Core', '8.252', '1.0%', '1.21', '59.3%', '59.5%', '0.0001'], ['Strength In Numbers', 'War', 'Trial', '6.929', '3.2%', '1.04', '59.3%', '59.6%', '0.0022'], ['Strength In Numbers', 'Neutral', 'Core', '5.954', '0.7%', '1.07', '59.2%', '59.4%', '0.0003'], ['Strength In Numbers', 'Magic', 'Genesis', '706', '0.9%', '1.60', '59.2%', '59.2%', '0.0005'], ['Strength In Numbers', 'Neutral', 'Core', '27.091', '3.4%', '1.15', '59.2%', '59.6%', '0.0001'], ['Strength In Numbers', 'Neutral', 'Core', '36.191', '4.5%', '1.12', '59.0%', '59.6%', '0.0001'], ['Strength In Numbers', 'Neutral', 'Genesis', '112', '0.0%', '1.00', '58.9%', '58.9%', '0.0295'], ['Strength In Numbers', 'Neutral', 'Genesis', '185', '0.0%', '1.03', '58.9%', '58.9%', '0.0088'], ['Strength In Numbers', 'Neutral', 'Core', '7.575', '0.9%', '1.25', '58.9%', '59.1%', '0.0001'], ['Strength In Numbers', 'Neutral', 'Core', '36.790', '4.6%', '1.23', '58.9%', '59.4%', '0.0001'], ['Strength In Numbers', 'Neutral', 'Core', '25.303', '3.1%', '1.16', '58.8%', '59.3%', '0.0002'], ['Strength In Numbers', 'Neutral', 'Core', '6.218', '0.8%', '1.16', '58.8%', '58.9%', '0.0001'], ['Strength In Numbers', 'Neutral', 'Trial', '571', '0.1%', '1.41', '58.7%', '58.7%', '0.0010'], ['Strength In Numbers', 'Neutral', 'Core', '30.556', '3.8%', '1.28', '58.6%', '59.0%', '0.0001'], ['Strength In Numbers', 'Magic', 'Genesis', '625', '0.8%', '1.96', '58.6%', '58.6%', '0.0165'], ['Strength In Numbers', 'Death', 'Genesis', '528', '0.7%', '1.00', '58.5%', '58.5%', '0.0550'], ['Strength In Numbers', 'Neutral', 'Core', '37.406', '4.6%', '1.21', '58.4%', '59.1%', '0.0001'], ['Strength In Numbers', 'Nature', 'Trial', '4.935', '2.2%', '1.00', '58.4%', '58.7%', '0.0588'], ['Strength In Numbers', 'War', 'Core', '2.878', '1.3%', '1.12', '58.4%', '58.4%', '0.0002'], ['Strength In Numbers', 'Deception', 'Genesis', '1.202', '1.4%', '1.00', '58.4%', '58.5%', '0.0800'], ['Strength In Numbers', 'Neutral', 'Core', '13.111', '1.6%', '1.20', '58.3%', '58.6%', '0.0001'], ['Highland Defender', 'Neutral', 'Core', '27.095', '3.4%' ...

# %%
colunas = ['Name', 'God', 'Set', 'Matches', 'In % of Decks', 'Copies', 'Deck win rate', 'Unique Deck WR','Est. Price']
df = pd.DataFrame(all_cards, columns=colunas)
df.head(30)
# Out:
#                       Name      God        Set Matches In % of Decks Copies  \
# 0   Magic Missile Launcher      War  Etherbots   1.688          0.8%   1.75
# 1   Magic Missile Launcher      War    Genesis   1.154          0.5%   1.00
# 2   Magic Missile Launcher      War    Genesis     251          0.1%   1.00
# 3   Magic Missile Launcher      War    Genesis     487          0.2%   1.33
# 4   Magic Missile Launcher    Magic    Genesis     360          0.4%   1.00
# 5   Magic Missile Launcher  Neutral       Core   7.098          0.9%   1.08
# 6   Magic Missile Launcher  Neutral       Core   9.632          1.2%   1.13
# 7   Magic Missile Launcher    Death    Genesis   2.222          3.2%   1.80
# 8   Magic Missile Launcher  Neutral       Core  20.327          2.5%   1.20
# 9   Magic Missile Launcher      War    Genesis   6.061          2.8%   1.79
# 10  Magic Missile Launcher      War    Genesis   1.155          0.5%   1.00
# 11  Magic Missile Launcher  Neutral    Genesis   1.750          0.2%   1.52
# 12  Magic Missile Launcher   Nature    Genesis   1.291          0.6%   1.06
# 13  Magic Missile Launcher      War      Trial   5.452          2.5%   1.00
# 14  Magic Missile Launcher  Neutral       Core  15.072          1.9%   1.13
# 15  Magic Missile Launcher  Neutral       Core  10.423          1.3%   1.08
# 16  Magic Missile Launcher  Neutral       Core  13.430          1.7%   1.11
# 17  Magic Missile Launcher  Neutral       Core   4.285          0.5%   1.08
# 18  Magic Missile Launcher  Neutral       Core  23.913          3.0%   1.13
# 19  Magic Missile Launcher  Neutral       Core   8.252          1.0%   1.21
# 20     Strength In Numbers      War      Trial   6.929          3.2%   1.04
# 21     Strength In Numbers  Neutral       Core   5.954          0.7%   1.07
# 22     Strength In Numbers    Magic    Genesis     706          0.9%   1.60
# 23     Strength In Numbers  Neutral       Core  27.091          3.4%   1.15
# 24     Strength In Numbers  Neutral       Core  36.191          4.5%   1.12
# 25     Strength In Numbers  Neutral    Genesis     112          0.0%   1.00
# 26     Strength In Numbers  Neutral    Genesis     185          0.0%   1.03
# 27     Strength In Numbers  Neutral       Core   7.575          0.9%   1.25
# 28     Strength In Numbers  Neutral       Core  36.790          4.6%   1.23
# 29     Strength In Numbers  Neutral       Core  25.303          3.1%   1.16
#
#    Deck win rate Unique Deck WR Est. Price
# 0          68.1%          68.3%     0.1770
# 1          64.6%          64.6%     0.1659
# 2          63.7%          63.7%     0.0335
# 3          63.2%          63.2%     0.0004
# 4          63.1%          63.1%     0.0449
# 5          62.7%          62.9%     0.0001
# 6          61.6%          61.8%     0.0001
# 7          61.1%          61.5%     0.1500
# 8          61.1%          61.5%     0.0001
# 9          60.7%          61.1%     0.0265
# 10         60.6%          60.7%     0.1379
# 11         60.2%          60.3%     0.0036
# 12         60.1%          60.2%     0.0148
# 13         60.1%          60.5%     0.0424
# 14         59.8%          60.1%     0.0003
# 15         59.7%          59.8%     0.0001
# 16         59.7%          60.0%     0.0001
# 17         59.6%          59.7%     0.0006
# 18         59.5%          60.0%     0.0001
# 19         59.3%          59.5%     0.0001
# 20         59.3%          59.6%     0.0022
# 21         59.2%          59.4%     0.0003
# 22         59.2%          59.2%     0.0005
# 23         59.2%          59.6%     0.0001
# 24         59.0%          59.6%     0.0001
# 25         58.9%          58.9%     0.0295
# 26         58.9%          58.9%     0.0088
# 27         58.9%          59.1%     0.0001
# 28         58.9%          59.4%     0.0001
# 29         58.8%          59.3%     0.0002

# %%
print(all_cards[0].prettify())
# Out:
# <div class="rt-tr-group" role="rowgroup">
#  <div class="rt-tr -odd" role="row">
#   <div class="rt-td no-padding-cell" role="gridcell" style="flex: 280 0 auto; width: 280px; max-width: 280px;">
#    <div class="card-ranking-cell">
#     <div class="card-image-item card-image-item-hoverable">
#      <div class="card-image-item-border">
#       <div class="card-image-item-background" style='background-image: url("https://images.godsunchained.com/art2/250/384.jpg");'>
#       </div>
#      </div>
#     </div>
#     <div class="card-ranking-name">
#      Magic Missile Launcher
#     </div>
#    </div>
#   </div>
#   <div class="rt-td react-table-cell" role="gridcell" style="flex: 100 0 auto; width: 100px; max-width: 100px;">
#    War
#   </div>
#   <div class="rt-td react-table-cell" role="gridcell" style="flex: 100 0 auto; width: 100px; max-width: 100px;">
#    Etherbots
#   </div>
#   <div class="rt-td react-table-cell" role="gridcell" style="flex: 80 0 auto; width: 80px; max-width: 80px;">
#    <div>
#     1.700
#    </div>
#   </div>
#   <div class="rt-td react-table-cell" role="gridcell" style="flex: 120 0 auto; width: 120px; max-width: 120px;">
#    0.8%
#   </div>
#   <div class="rt-td react-table-cell" role="gridcell" style="flex: 100 0 auto; width: 100px; max-width: 100px;">
#    1.75
#   </div>
#   <div class="rt-td react-table-cell" role="gridcell" style="flex: 120 0 auto; width: 120px; max-width: 120px;">
#    <div class="percentage-with-bar">
#     <div>
#      68.2%
#     </div>
#     <div class="percentage-line">
#      <div class="percentage-level" style="width: 68.1765%;">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="rt-td react-table-cell" role="gridcell" style="flex: 130 0 auto; width: 130px; max-width: 130px;">
#    <div class="percentage-with-bar">
#     <div>
#      68.4%
#     </div>
#     <div class="percentage-line">
#      <div class="percentage-level" style="width: 68.3929%;">
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="rt-td react-table-cell" role="gridcell" style="flex: 80 0 auto; width: 80px; max-width: 80px;">
#    <div class="deck-price-cell">
#     0.1770
#    </div>
#   </div>
#  </div>
# </div>

# %%
test = all_cards[0].findAll('div', attrs={'class':'rt-td react-table-cell'})
for atr in test:
    print(atr.text)
# Out:
# War
# Etherbots
# 1.700
# 0.8%
# 1.75
# 68.2%
# 68.4%
# 0.1770
