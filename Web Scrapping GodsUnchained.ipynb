# %% [markdown]
# # Web Scrapping GodsUnchained
# Nesse notebook vamos fazer um web scrapping da pagina https://gudecks.com/meta/card-rankings para pegar informações sobre as cartas e gerar um documendo csv.

# %% [markdown]
# ## 1. Programa que pega informações sobre as cartas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from time import sleep

options = Options()
options.add_argument('window-size=800,800')

navegador = webdriver.Chrome()
navegador.get('https://gudecks.com/meta/card-rankings')

sleep(10)

but = navegador.find_element(By.XPATH, '//*[@id="root"]/div[3]/button')
but.click()

sleep(0.5)

informations = [] # Todas as paginas
for i in range(49):
    informations.append(BeautifulSoup(navegador.page_source, 'html.parser'))
    but = navegador.find_element(By.XPATH, '//*[@id="root"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[3]/button')
    but.click()
    sleep(0.025)

all_cards = [] 
for site in informations:
    cards = site.findAll('div', attrs={'class':'rt-tr-group'})
    for card in cards:
        little_list = []
        try:
            little_list.append(card.find('div', attrs={'class':'card-ranking-name'}).text) # Nome da carta
        except:
            continue
        little_list.extend([atr.text for atr in card.findAll('div', attrs={'class':'rt-td react-table-cell'})]) #Info das cartas

        all_cards.append(little_list)
    
    

colunas = ['Name', 'God', 'Set', 'Matches', 'In % of Decks', 'Copies', 'Deck win rate', 'Unique Deck WR','Est. Price']
df = pd.DataFrame(all_cards, columns=colunas)
df
# Out:
# [['Magic Missile Launcher', 'War', 'Etherbots', '1.662', '0.8%', '1.75', '68.2%', '68.5%', '0.1770'], ['Avatar of War', 'War', 'Genesis', '1.139', '0.5%', '1.00', '64.8%', '64.8%', '0.1659'], ['Odin, Endless War', 'War', 'Genesis', '252', '0.1%', '1.00', '63.9%', '63.9%', '0.0335'], ['Reinforcements', 'War', 'Genesis', '487', '0.2%', '1.33', '63.0%', '63.0%', '0.0004'], ['Circe, Vengeful Sorceress', 'Magic', 'Genesis', '357', '0.4%', '1.00', '63.0%', '63.1%', '0.0449'], ["Pharaoh's Guard", 'Neutral', 'Core', '7.088', '0.9%', '1.08', '62.6%', '62.8%', '0.0001'], ['Eager Nobleborn', 'Neutral', 'Core', '9.622', '1.2%', '1.13', '61.6%', '61.8%', '0.0001'], ['Viking Warmaiden', 'Neutral', 'Core', '20.296', '2.5%', '1.20', '61.1%', '61.5%', '0.0001'], ['Apocalypse Now', 'Death', 'Genesis', '2.215', '3.1%', '1.80', '61.0%', '61.4%', '0.1500'], ['Master Tactician', 'War', 'Genesis', '6.008', '2.8%', '1.79', '60.7%', '61.1%', '0.0265'], ['Aeneas', 'War', 'Genesis', '1.148', '0.5%', '1.00', '60.5%', '60.6%', '0.1379'], ['Reflection Elementalist', 'Neutral', 'Genesis', '1.742', '0.2%', '1.52', '60.3%', '60.4%', '0.0036'], ['Hyrtacus, Brazen Hero', 'War', 'Trial', '5.413', '2.5%', '1.00', '60.1%', '60.5%', '0.0424'], ['Photogenesis', 'Nature', 'Genesis', '1.292', '0.6%', '1.06', '60.0%', '60.1%', '0.0148'], ['Viking Bloodguard', 'Neutral', 'Core', '15.043', '1.9%', '1.13', '59.8%', '60.0%', '0.0003'], ['Strix Hunter', 'Neutral', 'Core', '10.412', '1.3%', '1.08', '59.7%', '59.9%', '0.0001'], ['Duergar Priest', 'Neutral', 'Core', '13.412', '1.7%', '1.11', '59.7%', '60.0%', '0.0001'], ['Spartan', 'Neutral', 'Core', '4.281', '0.5%', '1.08', '59.6%', '59.7%', '0.0006'], ['Viking Outrider', 'Neutral', 'Core', '23.862', '3.0%', '1.13', '59.5%', '60.0%', '0.0001'], ['The Gatekeeper', 'Neutral', 'Genesis', '111', '0.0%', '1.00', '59.5%', '59.5%', '0.0295'], ['Ambitious Adventurer', 'Neutral', 'Core', '8.224', '1.0%', '1.21', '59.4%', '59.5%', '0.0001'], ["Heka's Enchantress", 'Magic', 'Genesis', '706', '0.9%', '1.60', '59.3%', '59.3%', '0.0005'], ['Strength In Numbers', 'War', 'Trial', '6.891', '3.2%', '1.04', '59.3%', '59.7%', '0.0022'], ['Solemn Lecturer', 'Neutral', 'Core', '5.936', '0.7%', '1.07', '59.2%', '59.4%', '0.0003'], ['Aether Battlescout', 'Neutral', 'Core', '27.032', '3.3%', '1.15', '59.2%', '59.7%', '0.0001'], ['Vanir Lion', 'Neutral', 'Core', '36.092', '4.5%', '1.12', '59.0%', '59.5%', '0.0001'], ['Crush Construct', 'Neutral', 'Genesis', '185', '0.0%', '1.03', '58.9%', '58.9%', '0.0088'], ['Arkmonian Anteater', 'Neutral', 'Core', '7.577', '0.9%', '1.25', '58.9%', '59.0%', '0.0001'], ['Amazon Spearsoul', 'Neutral', 'Core', '36.706', '4.5%', '1.23', '58.9%', '59.4%', '0.0001'], ['Ghost Marauder', 'Neutral', 'Core', '25.255', '3.1%', '1.16', '58.8%', '59.3%', '0.0002'], ['Tomb Torchbearer', 'Neutral', 'Core', '6.199', '0.8%', '1.16', '58.8%', '58.9%', '0.0001'], ['Lost In The Depths', 'Magic', 'Genesis', '625', '0.8%', '1.96', '58.7%', '58.7%', '0.0165'], ['Frumentarii Researcher', 'Neutral', 'Trial', '569', '0.1%', '1.40', '58.7%', '58.7%', '0.0010'], ['Wetlands Ogre', 'Neutral', 'Core', '30.472', '3.8%', '1.28', '58.6%', '59.1%', '0.0001'], ['Tribal Orc', 'Neutral', 'Core', '37.293', '4.6%', '1.22', '58.4%', '59.1%', '0.0001'], ['Chiron, the Teacher', 'Nature', 'Trial', '4.923', '2.2%', '1.00', '58.4%', '58.7%', '0.0588'], ['Signal Scouts', 'War', 'Core', '2.879', '1.3%', '1.12', '58.4%', '58.4%', '0.0002'], ['Death, Unborn', 'Death', 'Genesis', '528', '0.7%', '1.00', '58.3%', '58.3%', '0.0550'], ['Ranger Firstbow', 'Neutral', 'Core', '28.689', '3.6%', '1.19', '58.3%', '58.8%', '0.0001'], ['Highland Defender', 'Neutral', 'Core', '27.023', '3.3%', '1.10', '58.3%', '58.8%', '0.0001'], ['Jaguar Staff', 'Nature', 'Trial', '13.360', '6.1%', '1.35', '58.3%', '58.8%', '0.0035'], ['Avatar of Deception', 'Deception', 'Genesis', '1.194', '1.4%', '1.00', '58.3%', '58.4%', '0.0800'], ['Beastfury Shaman', 'Neutral', 'Core', '13.086', '1.6%', '1. ...

# %%
df.to_csv('godsunchained_cards_informations.csv')
